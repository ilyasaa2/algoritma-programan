# %%
print ('Nama: Ilyasa Abiyyu Wicaksono')
print ('\n')
print ('NPM: 2420506035')
print ('\n')
print ('Alamat: Wates Tengah RT05/RW02')
print ('\n')
print ('Tinggi Badan: 176')
print ('\n')
print ('Berat Badan: 57')
# Out:
# Nama: Ilyasa Abiyyu Wicaksono
#
#
# NPM: 2420506035
#
#
# Alamat: Wates Tengah RT05/RW02
#
#
# Tinggi Badan: 176
#
#
# Berat Badan: 57
