# %%
panjang = 20.5
lebar = 25
tinggi = 10

Keliling = 2* (panjang+lebar)
Luas = panjang*lebar
Volume = panjang*lebar*tinggi

print('panjang = ', panjang)
print('lebar = ' , lebar)
print('tinggi = ' , tinggi)
print('Keliling = ' , Keliling)
print('Volume = ' , Volume)
# Out:
# panjang =  20.5
# lebar =  25
# tinggi =  10
# Keliling =  91.0
# Volume =  5125.0
